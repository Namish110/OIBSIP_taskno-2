# %% [markdown]
# **Preparing the environment**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# **Data collection**

# %%
data = pd.read_csv('/content/Unemployment in India.csv')
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 763                  NaN                                       NaN    NaN
# 764                  NaN                                       NaN    NaN
# 765                  NaN                                       NaN    NaN
# 766                  NaN                                       NaN    NaN
# 767                  NaN                                       NaN    NaN
#
# [768 rows x 7 columns]

# %% [markdown]
# **Data Exploring**

# %%
#Dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
#Random 5 rows
data.sample(5)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 228       Odisha   30-04-2020    Monthly                             24.48
# 628   Puducherry   31-05-2020    Monthly                             75.00
# 251       Punjab   31-01-2020    Monthly                              9.69
# 200  Maharashtra   30-04-2020    Monthly                             25.28
# 263    Rajasthan   30-11-2019    Monthly                             10.47
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 228            5562449.0                                     25.16  Rural
# 628              64538.0                                     31.25  Urban
# 251            6189471.0                                     45.22  Rural
# 200           15014802.0                                     37.42  Rural
# 263           15278556.0                                     40.87  Rural

# %%
# Null values in Features
data.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
# Discriptive Statistics for numeric feature
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# max                                   72.570000

# %%
data['Area'].value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
data['Region'].value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
data[' Date'].value_counts()
# Out:
#  31-10-2019    55
#  30-11-2019    55
#  31-05-2019    54
#  30-06-2019    54
#  31-07-2019    54
#  31-08-2019    53
#  31-12-2019    53
#  31-01-2020    53
#  29-02-2020    53
#  30-09-2019    52
#  31-03-2020    52
#  30-04-2020    51
#  31-05-2020    51
#  30-06-2020    50
# Name:  Date, dtype: int64

# %%
data[' Frequency'].value_counts()
# Out:
# Monthly     381
#  Monthly    359
# Name:  Frequency, dtype: int64

# %%
# Unemployment Rate and People
data[' Estimated Employed'].corr(data[' Estimated Unemployment Rate (%)'])
# Out:
# -0.22287639952214783

# %%
# Dropping null values

Df2=data.dropna().drop(columns=[' Frequency'])
Df2
# Out:
#              Region         Date   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019                              3.65
# 1    Andhra Pradesh   30-06-2019                              3.05
# 2    Andhra Pradesh   31-07-2019                              3.75
# 3    Andhra Pradesh   31-08-2019                              3.32
# 4    Andhra Pradesh   30-09-2019                              5.17
# ..              ...          ...                               ...
# 749     West Bengal   29-02-2020                              7.55
# 750     West Bengal   31-03-2020                              6.67
# 751     West Bengal   30-04-2020                             15.63
# 752     West Bengal   31-05-2020                             15.22
# 753     West Bengal   30-06-2020                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139.0                                     43.24  Rural
# 1             11755881.0                                     42.05  Rural
# 2             12086707.0                                     43.50  Rural
# 3             12285693.0                                     43.97  Rural
# 4             12256762.0                                     44.68  Rural
# ..                   ...                                       ...    ...
# 749           10871168.0                                     44.09  Urban
# 750           10806105.0                                     43.34  Urban
# 751            9299466.0                                     41.20  Urban
# 752            9240903.0                                     40.67  Urban
# 753            9088931.0                                     37.57  Urban
#
# [740 rows x 6 columns]

# %%
# Renaming columns
# Reset Index
# Rounding Estimated Employee for better visualization

df3 =Df2.rename(columns={"Region" : "region", ' Date' : 'date', ' Estimated Unemployment Rate (%)' : 'est_unemp_perc', ' Estimated Employed' : 'est_mil_emp',
                          ' Estimated Labour Participation Rate (%)' : 'est_labour_perc', 'Area' : 'area'}).reset_index(drop = True)
df3['est_mil_emp'] = (df3['est_mil_emp'] / 1000000).round(2)
df3
# Out:
#              region         date  est_unemp_perc  est_mil_emp  \
# 0    Andhra Pradesh   31-05-2019            3.65        12.00
# 1    Andhra Pradesh   30-06-2019            3.05        11.76
# 2    Andhra Pradesh   31-07-2019            3.75        12.09
# 3    Andhra Pradesh   31-08-2019            3.32        12.29
# 4    Andhra Pradesh   30-09-2019            5.17        12.26
# ..              ...          ...             ...          ...
# 735     West Bengal   29-02-2020            7.55        10.87
# 736     West Bengal   31-03-2020            6.67        10.81
# 737     West Bengal   30-04-2020           15.63         9.30
# 738     West Bengal   31-05-2020           15.22         9.24
# 739     West Bengal   30-06-2020            9.86         9.09
#
#      est_labour_perc   area
# 0              43.24  Rural
# 1              42.05  Rural
# 2              43.50  Rural
# 3              43.97  Rural
# 4              44.68  Rural
# ..               ...    ...
# 735            44.09  Urban
# 736            43.34  Urban
# 737            41.20  Urban
# 738            40.67  Urban
# 739            37.57  Urban
#
# [740 rows x 6 columns]

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
# Searching for outliers
sns.boxplot(data=df3, x= 'region', y= 'est_unemp_perc')
plt.title('Detectiing outliers in Unemploment rates per region')
plt.ylabel('Unemloyment percentage')
plt.xticks(rotation = 90 )
plt.show()

# %% [markdown]
# ***Data Visualization***

# %%
sns.lineplot(data=df3, x='date', y='est_labour_perc', hue='area', errorbar= None)
plt.title('Percentage of labour participantion rate per month')
plt.ylabel('labour participantion rate')
plt.xticks(rotation= 70)
plt.figtext(x= 0.48, y= 0.2 , s= 'The participation rate\nof both areas reach\nits lowest in april 2020\nas it was the peak\nof the crisis')
plt.show()

# %% [markdown]
# Discovering the differences in unemployment percentages among regions should tell us the most affected region of the Covid-19 crisis

# %%
df5 = df3.groupby('region')[['est_unemp_perc']].mean().sort_values(by='est_unemp_perc',ascending= False)
df5.plot(kind='bar')
plt.title('Estimated unemployment percentage per region')
plt.ylabel('Unemployment percentage')
plt.xticks(rotation= 90)
plt.figtext(x= 0.19, y= 0.7, s= 'Tripura has the highest\nunemloyment percentage\nof all regions')
plt.show()
